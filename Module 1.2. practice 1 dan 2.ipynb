# %% [markdown]
# STTATISTIKA PROBABILITAS
#
#     Practice 1.2
#
#     1. Dalam suatu liga sepak bola, dipilih secara acak 10 pemain dari klub yang berbeda dan diketahui jumlah gol yang mereka raih dalam musim ini adalah: 19, 10, 10, 12, 13, 15, 14, 13, 9, 17. Lakukan analisis terhadap sebaran data dari dataset yang diberikan. Manakah ukuran sebaran yang paling mampu menggambarkan sebaran data dengan baik?

# %%
import numpy as np
import matplotlib.pyplot as plt

# Inisialisasi dataset
Gol_Terbanyak = [19, 10, 10, 12, 13, 15, 14, 13, 9, 17]
    
print(f"Jumlah Gol: {Gol_Terbanyak}")

# Mean
mean_Gol = sum(Gol_Terbanyak) / len(Gol_Terbanyak)
print("Mean Gol:", mean_Gol)

# Range
range_Gol = max(Gol_Terbanyak) - min(Gol_Terbanyak)
print("Range Gol:", range_Gol)

# Variance and Standard Deviation
variance_Gol = sum((x - mean_Gol) ** 2 for x in Gol_Terbanyak) / len(Gol_Terbanyak)
std_deviation_Gol = variance_Gol ** 0.5
print("Variance Gol:", variance_Gol)
print("Standard Deviation Gol:", std_deviation_Gol)

plt.hist(Gol_Terbanyak, bins=20, edgecolor='black', alpha=0.5, color='purple')

# Define the horizontal line coordinates
y = 1.5 # The y-coordinate where the line will be drawn
x1 = 4/70*1  # The x-coordinate of the start point
x2 = 66/70*1  # The x-coordinate of the end point

# Add a horizontal line
plt.axhline(y=y, xmin=x1, xmax=x2, color='red', linestyle='dashed', linewidth=1, label=f'Range = {range_Gol}')

# Add vertical line
plt.axvline(x=min(Gol_Terbanyak), color='blue', linestyle='dashed', linewidth=1, label=f'Min Data: {min(Gol_Terbanyak):.2f}')
plt.axvline(x=max(Gol_Terbanyak), color='blue', linestyle='dashed', linewidth=1, label=f'Max Data: {max(Gol_Terbanyak):.2f}')
plt.axvline(x=mean_Gol, color='black', linestyle='dashed', linewidth=1, label=f'Mean = {mean_Tinggi}')
plt.axvline(x=mean_Gol - std_deviation_Gol, color='brown', linestyle='dashed', linewidth=1, label=f'{mean_Gol-std_deviation_Gol:.2f}')
plt.axvline(x=mean_Gol + std_deviation_Gol, color='brown', linestyle='dashed', linewidth=1, label=f'{mean_Gol+std_deviation_Gol:.2f}')

# Add labels and title
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Range')
plt.title(f'Std Deviation = {std_deviation_Gol:.2f}')

# Add legend
plt.legend()

# Show the plot
plt.show()
# Out:
# Jumlah Gol: [19, 10, 10, 12, 13, 15, 14, 13, 9, 17]
# Mean Gol: 13.2
# Range Gol: 10
# Variance Gol: 9.16
# Standard Deviation Gol: 3.026549190084311

# %% [markdown]
#     2. Dalam tim olahraga, tinggi pemain adalah: 180 cm, 185 cm, 175 cm, 190 cm, 170 cm, 195 cm, 165 cm. Bagaimana sebaran data dari tinggi pemain ini?

# %%
import numpy as np
import matplotlib.pyplot as plt

# Inisialisasi dataset
Tinggi_Pemain = [180, 185, 175, 190, 170, 195, 165]
    
print(f"Tinggi Pemain: {Tinggi_Pemain}")

# Mean
mean_Tinggi = sum(Tinggi_Pemain) / len(Tinggi_Pemain)
print("Mean Tinggi Pemain:", mean_Tinggi)

# Range
range_Tinggi = max(Tinggi_Pemain) - min(Tinggi_Pemain)
print("Range Tinggi Pemain:", range_Tinggi)

# Variance and Standard Deviation
variance_Tinggi = sum((x - mean_Tinggi) ** 2 for x in Tinggi_Pemain) / len(Tinggi_Pemain)
std_deviation_Tinggi = variance_Tinggi ** 0.5
print("Variance Tinggi Pemain:", variance_Tinggi)
print("Standard Deviation Tinggi Pemain:", std_deviation_Tinggi)

plt.hist(Tinggi_Pemain, bins=20, edgecolor='black', alpha=0.5, color='purple')

# Define the horizontal line coordinates
y = 1.5 # The y-coordinate where the line will be drawn
x1 = 4/70*1  # The x-coordinate of the start point
x2 = 66/70*1  # The x-coordinate of the end point

# Add a horizontal line
plt.axhline(y=y, xmin=x1, xmax=x2, color='red', linestyle='dashed', linewidth=1, label=f'Range = {range_Tinggi}')

# Add vertical line
plt.axvline(x=min(Tinggi_Pemain), color='blue', linestyle='dashed', linewidth=1, label=f'Min Data: {min(Tinggi_Pemain):.2f}')
plt.axvline(x=max(Tinggi_Pemain), color='blue', linestyle='dashed', linewidth=1, label=f'Max Data: {max(Tinggi_Pemain):.2f}')
plt.axvline(x=mean_Tinggi, color='black', linestyle='dashed', linewidth=1, label=f'Mean = {mean_Tinggi}')
plt.axvline(x=mean_Tinggi - std_deviation_Tinggi, color='brown', linestyle='dashed', linewidth=1, label=f'{mean_Tinggi-std_deviation_Tinggi:.2f}')
plt.axvline(x=mean_Tinggi + std_deviation_Tinggi, color='brown', linestyle='dashed', linewidth=1, label=f'{mean_Tinggi+std_deviation_Tinggi:.2f}')

# Add labels and title
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Range')
plt.title(f'Std Deviation = {std_deviation_Tinggi:.2f}')

# Add legend
plt.legend()

# Show the plot
plt.show()
# Out:
# Tinggi Pemain: [180, 185, 175, 190, 170, 195, 165]
# Mean Tinggi Pemain: 180.0
# Range Tinggi Pemain: 30
# Variance Tinggi Pemain: 100.0
# Standard Deviation Tinggi Pemain: 10.0
